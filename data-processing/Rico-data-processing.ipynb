# %%
from os.path import join as pjoin
from DataInspector import DataInspector
import json

# %%
data = DataInspector(img_directory='/home/ml/Data/rico/combined/', json_directory='/home/ml/Data/rico/semantic/')

# %%
data.get_all_json_files()

# %%
'''
*******************************************
*** Collect Component by ComponentLabel ***
*******************************************
'''
start_point = 19820
end_point = 70000

bad_cases = []
for i, jfile in enumerate(data.json_files):
    if i < start_point:
        continue
    if i > end_point:
        break
    imgfile = data.generate_file_path(source_file=jfile, target_file_type='.jpg')
    print('\n********** [%.3f] %s **********' %(i/(end_point - start_point), jfile))
    try:
        data.load_gui_img_and_element(imgfile, jfile)
        data.save_elements_clips_by_compo_label('/home/ml/Data/rico/component/')
    except Exception as E:
        bad_cases.append(imgfile)
# Out:
# ********** [0.395] /home/ml/Data/rico/semantic/21608.json **********
# {'Toolbar': 1, 'Text': 2, 'Pager Indicator': 1}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21609.json **********
# {'Toolbar': 2, 'Text': 10, 'Pager Indicator': 1, 'Icon': 2, 'Card': 4, 'Text Button': 4, 'Radio Button': 2}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21610.json **********
# {'Toolbar': 3, 'Text': 28, 'Pager Indicator': 1, 'Icon': 4, 'Card': 11, 'Text Button': 17, 'Radio Button': 2, 'Advertisement': 1, 'Web View': 2}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21611.json **********
# {'Toolbar': 4, 'Text': 45, 'Pager Indicator': 1, 'Icon': 6, 'Card': 11, 'Text Button': 17, 'Radio Button': 2, 'Advertisement': 1, 'Web View': 2, 'Input': 5}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21612.json **********
# {'Toolbar': 5, 'Text': 54, 'Pager Indicator': 1, 'Icon': 9, 'Card': 14, 'Text Button': 20, 'Radio Button': 2, 'Advertisement': 2, 'Web View': 4, 'Input': 5, 'Image': 5, 'List Item': 7}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21613.json **********
# {'Toolbar': 6, 'Text': 60, 'Pager Indicator': 1, 'Icon': 14, 'Card': 16, 'Text Button': 21, 'Radio Button': 2, 'Advertisement': 3, 'Web View': 6, 'Input': 5, 'Image': 6, 'List Item': 7}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21614.json **********
# {'Toolbar': 7, 'Text': 75, 'Pager Indicator': 1, 'Icon': 18, 'Card': 19, 'Text Button': 36, 'Radio Button': 2, 'Advertisement': 4, 'Web View': 8, 'Input': 5, 'Image': 8, 'List Item': 15, 'Drawer': 1}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21615.json **********
# {'Toolbar': 8, 'Text': 82, 'Pager Indicator': 1, 'Icon': 25, 'Card': 22, 'Text Button': 37, 'Radio Button': 2, 'Advertisement': 4, 'Web View': 8, 'Input': 5, 'Image': 9, 'List Item': 15, 'Drawer': 1}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21616.json **********
# {'Toolbar': 9, 'Text': 90, 'Pager Indicator': 1, 'Icon': 27, 'Card': 22, 'Text Button': 37, 'Radio Button': 2, 'Advertisement': 5, 'Web View': 10, 'Input': 10, 'Image': 9, 'List Item': 15, 'Drawer': 1}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21617.json **********
# {'Toolbar': 9, 'Text': 91, 'Pager Indicator': 1, 'Icon': 27, 'Card': 22, 'Text Button': 38, 'Radio Button': 2, 'Advertisement': 5, 'Web View': 10, 'Input': 11, 'Image': 9, 'List Item': 15, 'Drawer': 1}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21618.json **********
# {'Toolbar': 10, 'Text': 95, 'Pager Indicator': 1, 'Icon': 29, 'Card': 23, 'Text Button': 39, 'Radio Button': 2, 'Advertisement': 5, 'Web View': 10, 'Input': 12, 'Image': 15, 'List Item': 16, 'Drawer': 1}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21619.json **********
# {'Toolbar': 11, 'Text': 102, 'Pager Indicator': 1, 'Icon': 31, 'Card': 23, 'Text Button': 40, 'Radio Button': 2, 'Advertisement': 5, 'Web View': 10, 'Input': 12, 'Image': 21, 'List Item': 16, 'Drawer': 1}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21620.json **********
# {'Toolbar': 11, 'Text': 102, 'Pager Indicator': 1, 'Icon': 31, 'Card': 23, 'Text Button': 40, 'Radio Button': 2, 'Advertisement': 5, 'Web View': 10, 'Input': 12, 'Image': 21, 'List Item': 16, 'Drawer': 1}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21621.json **********
# {'Toolbar': 12, 'Text': 119, 'Pager Indicator': 1, 'Icon': 33, 'Card': 23, 'Text Button': 40, 'Radio Button': 2, 'Advertisement': 5, 'Web View': 11, 'Input': 18, 'Image': 23, 'List Item': 23, 'Drawer': 1, 'Date Picker': 1, 'Number Stepper': 3}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21622.json **********
# {'Toolbar': 13, 'Text': 123, 'Pager Indicator': 1, 'Icon': 35, 'Card': 23, 'Text Button': 43, 'Radio Button': 2, 'Advertisement': 5, 'Web View': 12, 'Input': 20, 'Image': 24, 'List Item': 24, 'Drawer': 1, 'Date Picker': 1, 'Number Stepper': 3}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21623.json **********
# {'Toolbar': 14, 'Text': 137, 'Pager Indicator': 1, 'Icon': 37, 'Card': 23, 'Text Button': 45, 'Radio Button': 2, 'Advertisement': 5, 'Web View': 13, 'Input': 24, 'Image': 26, 'List Item': 32, 'Drawer': 1, 'Date Picker': 2, 'Number Stepper': 6}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21624.json **********
# {'Toolbar': 15, 'Text': 140, 'Pager Indicator': 1, 'Icon': 41, 'Card': 23, 'Text Button': 48, 'Radio Button': 2, 'Advertisement': 5, 'Web View': 14, 'Input': 25, 'Image': 26, 'List Item': 33, 'Drawer': 1, 'Date Picker': 2, 'Number Stepper': 6}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21625.json **********
# {'Toolbar': 16, 'Text': 142, 'Pager Indicator': 1, 'Icon': 43, 'Card': 23, 'Text Button': 48, 'Radio Button': 2, 'Advertisement': 5, 'Web View': 14, 'Input': 25, 'Image': 27, 'List Item': 33, 'Drawer': 1, 'Date Picker': 2, 'Number Stepper': 6}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21626.json **********
# {'Toolbar': 16, 'Text': 148, 'Pager Indicator': 1, 'Icon': 43, 'Card': 23, 'Text Button': 48, 'Radio Button': 2, 'Advertisement': 5, 'Web View': 14, 'Input': 25, 'Image': 32, 'List Item': 33, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21627.json **********
# {'Toolbar': 17, 'Text': 152, 'Pager Indicator': 1, 'Icon': 45, 'Card': 23, 'Text Button': 48, 'Radio Button': 2, 'Advertisement': 6, 'Web View': 14, 'Input': 25, 'Image': 35, 'List Item': 33, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6}
#
# ********** [0.395] /home/ml/Data/rico/semantic/21628.json **********
# {'Toolbar': 18, 'Text': 166, 'Pager Indicator': 1, 'Icon': 49, 'Card': 23, 'Text Button': 50, 'Radio Button': 2, 'Advertisement': 6, 'Web View': 14, 'Input': 26, 'Image': 44, 'List Item': 33, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image':
 'List Item': 41, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 1, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21652.json **********
# {'Toolbar': 25, 'Text': 247, 'Pager Indicator': 2, 'Icon': 80, 'Card': 23, 'Text Button': 67, 'Radio Button': 2, 'Advertisement': 7, 'Web View': 23, 'Input': 46, 'Image': 75, 'List Item': 41, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 1, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21653.json **********
# {'Toolbar': 25, 'Text': 248, 'Pager Indicator': 2, 'Icon': 80, 'Card': 23, 'Text Button': 69, 'Radio Button': 2, 'Advertisement': 7, 'Web View': 23, 'Input': 46, 'Image': 78, 'List Item': 41, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 1, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21654.json **********
# {'Toolbar': 25, 'Text': 251, 'Pager Indicator': 2, 'Icon': 80, 'Card': 23, 'Text Button': 70, 'Radio Button': 2, 'Advertisement': 7, 'Web View': 23, 'Input': 46, 'Image': 81, 'List Item': 41, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 1, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21655.json **********
# {'Toolbar': 25, 'Text': 254, 'Pager Indicator': 2, 'Icon': 80, 'Card': 23, 'Text Button': 71, 'Radio Button': 2, 'Advertisement': 7, 'Web View': 23, 'Input': 46, 'Image': 84, 'List Item': 41, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 1, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21656.json **********
# {'Toolbar': 26, 'Text': 263, 'Pager Indicator': 2, 'Icon': 82, 'Card': 23, 'Text Button': 76, 'Radio Button': 2, 'Advertisement': 8, 'Web View': 25, 'Input': 46, 'Image': 84, 'List Item': 41, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 1, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21657.json **********
# {'Toolbar': 27, 'Text': 272, 'Pager Indicator': 2, 'Icon': 83, 'Card': 23, 'Text Button': 79, 'Radio Button': 2, 'Advertisement': 8, 'Web View': 25, 'Input': 46, 'Image': 84, 'List Item': 41, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 1, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21658.json **********
# {'Toolbar': 27, 'Text': 272, 'Pager Indicator': 2, 'Icon': 83, 'Card': 23, 'Text Button': 80, 'Radio Button': 2, 'Advertisement': 8, 'Web View': 25, 'Input': 46, 'Image': 84, 'List Item': 41, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 1, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21659.json **********
# {'Toolbar': 27, 'Text': 281, 'Pager Indicator': 2, 'Icon': 83, 'Card': 23, 'Text Button': 80, 'Radio Button': 2, 'Advertisement': 8, 'Web View': 25, 'Input': 46, 'Image': 84, 'List Item': 41, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 2, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21660.json **********
# {'Toolbar': 28, 'Text': 298, 'Pager Indicator': 2, 'Icon': 89, 'Card': 23, 'Text Button': 81, 'Radio Button': 2, 'Advertisement': 10, 'Web View': 29, 'Input': 46, 'Image': 96, 'List Item': 41, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 2, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21661.json **********
# {'Toolbar': 29, 'Text': 302, 'Pager Indicator': 2, 'Icon': 93, 'Card': 23, 'Text Button': 82, 'Radio Button': 2, 'Advertisement': 12, 'Web View': 33, 'Input': 46, 'Image': 98, 'List Item': 41, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 2, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21662.json **********
# {'Toolbar': 30, 'Text': 317, 'Pager Indicator': 2, 'Icon': 93, 'Card': 23, 'Text Button': 83, 'Radio Button': 2, 'Advertisement': 12, 'Web View': 33, 'Input': 46, 'Image': 112, 'List Item': 41, 'Drawer': 2, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 2, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21663.json **********
# {'Toolbar': 30, 'Text': 323, 'Pager Indicator': 2, 'Icon': 96, 'Card': 23, 'Text Button': 83, 'Radio Button': 2, 'Advertisement': 12, 'Web View': 33, 'Input': 46, 'Image': 114, 'List Item': 41, 'Drawer': 3, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 2, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21664.json **********
# {'Toolbar': 31, 'Text': 356, 'Pager Indicator': 2, 'Icon': 103, 'Card': 24, 'Text Button': 83, 'Radio Button': 2, 'Advertisement': 12, 'Web View': 33, 'Input': 47, 'Image': 120, 'List Item': 41, 'Drawer': 3, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 2, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21665.json **********
# {'Toolbar': 32, 'Text': 385, 'Pager Indicator': 2, 'Icon': 114, 'Card': 25, 'Text Button': 83, 'Radio Button': 2, 'Advertisement': 12, 'Web View': 33, 'Input': 48, 'Image': 121, 'List Item': 41, 'Drawer': 3, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 2, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21666.json **********
# {'Toolbar': 33, 'Text': 392, 'Pager Indicator': 2, 'Icon': 117, 'Card': 26, 'Text Button': 84, 'Radio Button': 2, 'Advertisement': 12, 'Web View': 33, 'Input': 48, 'Image': 121, 'List Item': 41, 'Drawer': 3, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 2, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21667.json **********
# {'Toolbar': 34, 'Text': 411, 'Pager Indicator': 2, 'Icon': 118, 'Card': 26, 'Text Button': 84, 'Radio Button': 2, 'Advertisement': 12, 'Web View': 33, 'Input': 48, 'Image': 121, 'List Item': 41, 'Drawer': 3, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 2, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21668.json **********
# {'Toolbar': 35, 'Text': 429, 'Pager Indicator': 2, 'Icon': 119, 'Card': 26, 'Text Button': 84, 'Radio Button': 2, 'Advertisement': 12, 'Web View': 33, 'Input': 48, 'Image': 121, 'List Item': 41, 'Drawer': 3, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 2, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21669.json **********
# {'Toolbar': 36, 'Text': 439, 'Pager Indicator': 2, 'Icon': 126, 'Card': 27, 'Text Button': 85, 'Radio Button': 2, 'Advertisement': 12, 'Web View': 33, 'Input': 48, 'Image': 122, 'List Item': 41, 'Drawer': 3, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 2, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21670.json **********
# {'Toolbar': 36, 'Text': 442, 'Pager Indicator': 2, 'Icon': 126, 'Card': 27, 'Text Button': 87, 'Radio Button': 2, 'Advertisement': 12, 'Web View': 33, 'Input': 48, 'Image': 123, 'List Item': 41, 'Drawer': 3, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 2, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21671.json **********
# {'Toolbar': 36, 'Text': 445, 'Pager Indicator': 2, 'Icon': 126, 'Card': 27, 'Text Button': 89, 'Radio Button': 2, 'Advertisement': 12, 'Web View': 33, 'Input': 48, 'Image': 124, 'List Item': 41, 'Drawer': 3, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 2, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21672.json **********
# {'Toolbar': 36, 'Text': 445, 'Pager Indicator': 2, 'Icon': 126, 'Card': 27, 'Text Button': 90, 'Radio Button': 2, 'Advertisement': 12, 'Web View': 33, 'Input': 48, 'Image': 126, 'List Item': 41, 'Drawer': 3, 'Date Picker': 2, 'Number Stepper': 6, 'Background Image': 5, 'Modal': 2, 'Checkbox': 1, 'Slider': 1}
#
# ********** [0.396] /home/ml/Data/rico/semantic/21673.json **********
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-64bb35d405b0> in <module>
#      17     try:
#      18         data.load_gui_img_and_element(imgfile, jfile)
# ---> 19         data.save_elements_clips_by_compo_label('/home/ml/Data/rico/component/')
#      20     except Exception as E:
#      21         bad_cases.append(imgfile)
#
# ~/Code/github/GUI-Semantics/data-processing/DataInspector.py in save_elements_clips_by_compo_label(self, output_dir)
#      63         Save Element clips into folders according to the ComponentLabel
#      64         '''
# ---> 65         self.current_gui.save_elements_clips_by_compo_label(output_dir, self.element_class_count)
#      66
#      67     def save_icons_clips_by_icon_class(self, output_dir):
#
# ~/Code/github/GUI-Semantics/data-processing/GUIData.py in save_elements_clips_by_compo_label(self, output_dir, elements_count)
#      80                 elements_count[ele['componentLabel']] += 1
#      81             clip_name = str(self.gui_name) + '-' + str(i) + '.jpg'
# ---> 82             cv2.imwrite(pjoin(compo_cls_dir, clip_name), clip)
#      83         print(elements_count)
#      84
#
# KeyboardInterrupt:

# %%
for e in data.current_gui.elements:
    print(e, '\n')
# Out:
# {'resource-id': 'com.tripomatic:id/toolbar', 'clickable': False, 'class': 'android.support.v7.widget.Toolbar', 'bounds': [0, 0, 1440, 280], 'componentLabel': 'Toolbar', 'id': 1, 'children-id': [2, 3]}
#
# {'text': 'Template Detail', 'clickable': False, 'class': 'android.support.v7.widget.AppCompatTextView', 'bounds': [252, 135, 744, 228], 'componentLabel': 'Text', 'id': 2}
#
# {'iconClass': 'arrow_backward', 'bounds': [0, 84, 196, 280], 'clickable': True, 'class': 'android.support.v7.widget.AppCompatImageButton', 'componentLabel': 'Icon', 'id': 3}
#
# {'resource-id': 'com.tripomatic:id/cv_button', 'clickable': False, 'class': 'android.support.v7.widget.CardView', 'bounds': [0, 2056, 1440, 2392], 'componentLabel': 'Card', 'id': 4, 'children-id': [5]}
#
# {'text': 'Use this template', 'resource-id': 'com.tripomatic:id/btn_use_template', 'clickable': True, 'class': 'android.support.v7.widget.AppCompatButton', 'bounds': [84, 2140, 1356, 2308], 'componentLabel': 'Text Button', 'id': 5}
#
# {'text': 'DESCRIPTION', 'clickable': False, 'class': 'android.support.v7.widget.AppCompatTextView', 'bounds': [84, 331, 395, 397], 'componentLabel': 'Text', 'id': 8}
#
# {'text': 'PLACES', 'clickable': False, 'class': 'android.support.v7.widget.AppCompatTextView', 'bounds': [629, 331, 810, 397], 'componentLabel': 'Text', 'id': 9}
#
# {'resource-id': 'com.tripomatic:id/wv_map', 'clickable': True, 'class': 'android.webkit.WebView', 'bounds': [0, 448, 1440, 2056], 'componentLabel': 'Web View', 'id': 10}

# %%
name = '4'
data.load_gui_img_and_element('/home/ml/Data/rico/combined/'+name+'.jpg', '/home/ml/Data/rico/semantic/'+name+'.json', show=False)

# %%
data.save_icons_clips_by_icon_class('/home/ml/Data/rico/icon/')
# Out:
# {'arrow_backward': 1, 'share': 1, 'emoji': 1, 'refresh': 1}

# %%
'''
**********************************
*** Collect Icons by iconClass ***
**********************************
'''
start_point = 0
end_point = 70000

bad_cases = []
for i, jfile in enumerate(data.json_files):
    if i < start_point:
        continue
    if i > end_point:
        break
    imgfile = data.generate_file_path(source_file=jfile, target_file_type='.jpg')
    print('\n********** [%.3f] %s **********' %(i/(end_point - start_point), jfile))
    try:
        data.load_gui_img_and_element(imgfile, jfile)
        data.save_icons_clips_by_icon_class('/home/ml/Data/rico/icon/')
    except Exception as E:
        bad_cases.append(imgfile)
