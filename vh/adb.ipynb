# %%
from Device import Device
from ppadb.client import Client as AdbClient
client = AdbClient(host="127.0.0.1", port=5037)
device = Device(client.devices()[0], 'data')

# %%
device.cap_vh()
# Out:
# Save view hierarchy to data\emulator-5554.json

# %%
device.cap_screenshot()
# Out:
# Save screenshot to data\emulator-5554.png

# %%
device.cvt_vh_to_rico_format()
# Out:
# Save reformatted vh to data\emulator-5554.json

# %%
device.vh
# Out:
# {'activity': {'root': {'text': '',
#    'resource-id': '',
#    'class': 'android.widget.FrameLayout',
#    'package': 'com.twitter.android',
#    'content-desc': '',
#    'checkable': 'false',
#    'checked': 'false',
#    'clickable': 'false',
#    'enabled': 'true',
#    'focusable': 'false',
#    'focused': 'false',
#    'scrollable': 'false',
#    'long-clickable': 'false',
#    'password': 'false',
#    'selected': 'false',
#    'bounds': [0, 0, 1080, 2214],
#    'children': [{'text': '',
#      'resource-id': '',
#      'class': 'android.widget.LinearLayout',
#      'package': 'com.twitter.android',
#      'content-desc': '',
#      'checkable': 'false',
#      'checked': 'false',
#      'clickable': 'false',
#      'enabled': 'true',
#      'focusable': 'false',
#      'focused': 'false',
#      'scrollable': 'false',
#      'long-clickable': 'false',
#      'password': 'false',
#      'selected': 'false',
#      'bounds': [0, 0, 1080, 2214],
#      'children': [{'text': '',
#        'resource-id': '',
#        'class': 'android.widget.FrameLayout',
#        'package': 'com.twitter.android',
#        'content-desc': '',
#        'checkable': 'false',
#        'checked': 'false',
#        'clickable': 'false',
#        'enabled': 'true',
#        'focusable': 'false',
#        'focused': 'false',
#        'scrollable': 'false',
#        'long-clickable': 'false',
#        'password': 'false',
#        'selected': 'false',
#        'bounds': [0, 66, 1080, 2214],
#        'children': [{'text': '',
#          'resource-id': 'com.twitter.android:id/action_bar_root',
#          'class': 'android.widget.FrameLayout',
#          'package': 'com.twitter.android',
#          'content-desc': '',
#          'checkable': 'false',
#          'checked': 'false',
#          'clickable': 'false',
#          'enabled': 'true',
#          'focusable': 'false',
#          'focused': 'false',
#          'scrollable': 'false',
#          'long-clickable': 'false',
#          'password': 'false',
#          'selected': 'false',
#          'bounds': [0, 66, 1080, 2214],
#          'children': [{'text': '',
#            'resource-id': 'android:id/content',
#            'class': 'android.widget.FrameLayout',
#            'package': 'com.twitter.android',
#            'content-desc': '',
#            'checkable': 'false',
#            'checked': 'false',
#            'clickable': 'false',
#            'enabled': 'true',
#            'focusable': 'false',
#            'focused': 'false',
#            'scrollable': 'false',
#            'long-clickable': 'false',
#            'password': 'false',
#            'selected': 'false',
#            'bounds': [0, 66, 1080, 2214],
#            'children': [{'text': '',
#              'resource-id': 'com.twitter.android:id/drawer_layout',
#              'class': 'androidx.drawerlayout.widget.DrawerLayout',
#              'package': 'com.twitter.android',
#              'content-desc': '',
#              'checkable': 'false',
#              'checked': 'false',
#              'clickable': 'false',
#              'enabled': 'true',
#              'focusable': 'false',
#              'focused': 'false',
#              'scrollable': 'false',
#              'long-clickable': 'false',
#              'password': 'false',
#              'selected': 'false',
#              'bounds': [0, 66, 1080, 2214],
#              'children': [{'text': '',
#                'resource-id': 'com.twitter.android:id/root_coordinator_layout',
#                'class': 'android.widget.ScrollView',
#                'package': 'com.twitter.android',
#                'content-desc': '',
#                'checkable': 'false',
#                'checked': 'false',
#                'clickable': 'false',
#                'enabled': 'true',
#                'focusable': 'false',
#                'focused': 'false',
#                'scrollable': 'true',
#                'long-clickable': 'false',
#                'password': 'false',
#                'selected': 'false',
#                'bounds': [0, 66, 1080, 2214],
#                'children': [{'text': '',
#                  'resource-id': 'com.twitter.android:id/pager',
#                  'class': 'androidx.viewpager.widget.ViewPager',
#                  'package': 'com.twitter.android',
#                  'content-desc': '',
#                  'checkable': 'false',
#                  'checked': 'false',
#                  'clickable': 'false',
#                  'enabled': 'true',
#                  'focusable': 'true',
#                  'focused': 'false',
#                  'scrollable': 'true',
#                  'long-clickable': 'false',
#                  'password': 'false',
#                  'selected': 'false',
#                  'bounds': [0, 66, 1080, 2214],
#                  'children': [{'text': '',
#                    'resource-id': 'com.twitter.android:id/view_pager',
#                    'class': 'androidx.viewpager.widget.ViewPager',
#                    'package': 'com.twitter.android',
#                    'content-desc': '',
#                    'checkable': 'false',
#                    'checked': 'false',
#                    'clickable': 'false',
#                    'enabled': 'true',
#                    'focusable': 'true',
#                    'focused': 'false',
#                    'scrollable': 'true',
#                    'long-clickable': 'false',
#                    'password': 'false',
#                    'selected': 'false',
#                    'bounds': [0, 66, 1080, 2060],
#                    'children': [{'text': '',
#                      'resource-id': 'com.twitter.android:id/tab_layout',
#                      'class': 'android.widget.HorizontalScrollView',
#                      'package': 'com.twitter.android',
#                      'content-desc': '',
#                      'checkable': 'false',
#                      'checked': 'false',
#                      'clickable': 'false',
#                      'enabled': 'true',
#                      'focusable': 'true',
#                      'focused': 'false',
#                      'scrollable': 'false',
#                      'long-clickable': 'false',
#                      'password': 'false',
#                      'selected': 'false',
#                      'bounds': [0, 66, 1080, 198],
#                      'children': [{'text': '',
#                        'resource-id': '',
#                        'class': 'android.widget.LinearLayout',
#                        'package': 'com.twitter.android',
#                        'content-desc': '',
#                        'checkable': 'false',
#                        'checked': 'false',
#                        'clickable': 'false',
#                        'enabled': 'true',
#                        'focusable': 'false',
#                        'focused': 'false',
#                        'scrollable': 'false',
#                        'long-clickable': 'false',
#                        'password': 'false',
#                        'selected': 'false',
#                        'bounds': [0, 66, 1080, 198],
#                        'children': [{'text': '',
#                          'resource-id': '',
#                          'class': 'android.widget.LinearLayout',
#                          'package': 'com.twitter.android',
#                          'content-desc': 'For you',
#                          'checkable': 'false',
#                          'checked': 'false',
#                          'clickable': 'false',
#                          'enabled': 'true',
#                          'focusable': 'true',
#                          'focused': 'false',
#                          'scrollable': 'false',
#                          'long-clickable': 'false',
#                          'password': 'false',
#                          'selected': 'true',
#                          'bounds': [0, 66, 528, 198],
#                          'children': [{'text': 'For you',
#                            'resource-id': '',
#                            'class': 'android.widget.TextView',
#                            'package': 'com.twitter.android',
#                            'content-desc': '',
#                            'checkable': 'false',
#                            'checked': 'false',
#                            'clickable': 'false',
#                            'enabled': 'true',
#                            'focusable': 'false',
#                            'focused': 'false',
#                            'scrollable': 'false',
#                            'long-clickable': 'false',
#                            'password': 'false',
#                            'selected': 'true',
#                            'bounds': [187, 107, 341, 157]}]},
#                         {'text': '',
#                          'resource-id': '',
#                          'class': 'android.widget.LinearLayout',
#                          'package': 'com.twitter.android',
#                          'content-desc': 'Following',
#                          'checkable': 'false',
#                          'checked': 'false',
#                          'clickable': 'true',
#                          'enabled': 'true',
#                          'focusable': 'true',
#                          'focused': 'false',
#                          'scrollable': 'false',
#                          'long-clickable': 'false',
#                          'password': 'false',
#                          'selected': 'false',
#                          'bounds': [528, 66, 1080, 198],
#                          'children': [{'text': 'Following',
#                            'resource-id': '',
#                            'class': 'android.widget.TextView',
#                            'package': 'com.twitter.android',
#                            'content-desc': '',
#                            'checkable': 'false',
#                            'checked': 'false',
#                            'clickable': 'false',
#                            'enabled': 'true',
#                            'focusable': 'false',
#                            'focused': 'false',
#                            'scrollable': 'false',
#                            'long-clickable': 'false',
#                            'password': 'false',
#                            'selected': 'false',
#                            'bounds': [715, 107, 893, 157]}]}]}]},
#                     {'text': '',
#                      'resource-id': 'com.twitter.android:id/nested_coordinator_layout',
#                      'class': 'android.widget.ScrollView',
#                      'package': 'com.twitter.android',
#                      'content-desc': '',
#                      'checkable': 'false',
#                      'checked': 'false',
#                      'clickable': 'false',
#                      'enabled': 'true',
#                      'focusable': 'false',
#                      'focused': 'false',
#                      'scrollable': 'true',
#                      'long-clickable': 'false',
#                      'password': 'false',
#                      'selected': 'false',
#                      'bounds': [0, 198, 1080, 2060],
#                      'children': [{'text': '',
#                        'resource-id': 'com.twitter.android:id/timeline_container',
#                        'class': 'android.widget.FrameLayout',
#                        'package': 'com.twitter.android',
#                        'content-desc': '',
#                        'checkable': 'false',
#                        'checked': 'false',
#                        'clickable': 'false',
#                        'enabled': 'true',
#                        'focusable': 'false',
#                        'focused': 'false',
#                        'scrollable': 'false',
#                        'long-clickable': 'false',
#                        'password': 'false',
#                        'selected': 'false',
#                        'bounds': [0, 198, 1080, 2060],
#                        'children': [{'text': '',
#                          'resource-id': 'com.twitter.android:id/pinned_header_container',
#                          'class': 'android.widget.FrameLayout',
#                          'package': 'com.twitter.android',
#                          'content-desc': '',
#                          'checkable': 'false',
#                          'checked': 'false',
#                          'clickable': 'false',
#                          'enabled': 'true',
#                          'focusable': 'false',
#                          'focused': 'false',
#                          'scrollable': 'false',
#                          'long-clickable': 'false',
#                          'password': 'false',
#                          'selected': 'false',
#                          'bounds': [0, 198, 1080, 2060],
#                          'children': [{'text': '',
#                            'resource-id': '',
#                            'class': 'android.view.ViewGroup',
#                            'package': 'com.twitter.android',
#                            'content-desc': '',
#                            'checkable': 'false',
#                            'checked': 'false',
#                            'clickable': 'false',
#                            'enabled': 'false',
#                            'focusable': 'false',
#                            'focused': 'false',
#                            'scrollable': 'false',
#                            'long-clickable': 'false',
#                            'password': 'false',
#                            'selected': 'false',
#                            'bounds': [0, 198, 1080, 2060],
#                            'children': [{'text': '',
#                              'resource-id': 'android:id/list',
#                              'class': 'androidx.recyclerview.widget.RecyclerView',
#                              'package': 'com.twitter.android',
#                              'content-desc': 'Home timeline list',
#                              'checkable': 'false',
#                              'checked': 'false',
#                              'clickable': 'false',
#                              'enabled': 'true',
#                              'focusable': 'true',
#                              'focused': 'true',
#                              'scrollable': 'true',
#                              'long-clickable': 'false',
#                              'password': 'false',
#                              'selected': 'false',
#                              'bounds': [0, 198, 1080, 2060],
#                              'children': [{'text': '',
#                                'resource-id': '',
#                                'class': 'android.view.ViewGroup',
#                                'package': 'com.twitter.android',
#                                'content-desc': '',
#                                'checkable': 'false',
#                                'checked': 'false',
#                                'clickable': 'true',
#                                'enabled': 'true',
#                                'focusable': 'true',
#                                'focused': 'false',
#                                'scrollable': 'false',
#                                'long-clickable': 'true',
#                                'password': 'false',
#                                'selected': 'false',
#                                'bounds': [0, 198, 1080, 2060],
#                                'children': [{'text': '',
#                                  'resource-id': 'com.twitter.android:id/outer_layout_row_view_tweet',
#                                  'class': 'android.widget.LinearLayout',
#                                  'package': 'com.twitter.android',
#                                  'content-desc': '',
#                                  'checkable': 'false',
#                                  'checked': 'false',
#                                  'clickable': 'false',
#                                  'enabled': 'true',
#                                  'focusable': 'false',
#                                  'focused': 'false',
#                                  'scrollable': 'false',
#                                  'long-clickable': 'false',
#                                  'password': 'false',
#                                  'selected': 'false',
#                                  'bounds': [0, 198, 1080, 2060],
#                                  'children': [{'text': '',
#                                    'resource-id': 'com.twitter.android:id/row',
#                                    'class': 'android.view.ViewGroup',
#                                    'package': 'com.twitter.android',
#                                    'content-desc': 'Garry Tan é™ˆå˜‰å…´ @garrytan Verified.    Quoted. Walter Kirn @walterkirn Verified.  Writers may wish to rethink their ambitions. If their work should prove lastng, it may end up being tortured for all eternity\n\nThis is not mere "sensitivity" editing, by the way. This is blunt, agenda-driven rewriting. It is idea injection. And it will be continual once it starts pic.twitter.com/LX6ZSpPgui.     Garry Tan é™ˆå˜‰å…´ @garrytan Verified.  Added George Orwell, 1984: â€œEvery record has been destroyed or falsified, every book has been rewritten, every picture has been repainted, every statue and street and building has been renamed, every date has been altered. And that process is continuing day by day and minute by minute.â€¦.       Elon Musk replied.     feb 20.  191 replies.  1253 retweets.  6182 likes.  3587698 verified views. ',
#                                    'checkable': 'false',
#                                    'checked': 'false',
#                                    'clickable': 'false',
#                                    'enabled': 'true',
#                                    'focusable': 'false',
#                                    'focused': 'false',
#                                    'scrollable': 'false',
#                                    'long-clickable': 'false',
#                                    'password': 'false',
#                                    'selected': 'false',
#                                    'bounds': [0, 198, 1080, 2060],
#                                    'children': [{'text': '',
#                                      'resource-id': 'com.twitter.android:id/tweet_profile_image_container',
#                                      'class': 'android.widget.FrameLayout',
#                                      'package': 'com.twitter.android',
#                                      'content-desc': '',
#                                      'checkable': 'false',
#                                      'checked': 'false',
#                                      'clickable': 'false',
#                                      'enabled': 'true',
#                                      'focusable': 'false',
#                                      'focused': 'false',
#                                      'scrollable': 'false',
#                                      'long-clickable': 'false',
#                                      'password': 'false',
#                                      'selected': 'false',
#                                      'bounds': [33, 198, 182, 270],
#                                      'children': [{'text': '',
#                                        'resource-id': 'com.twitter.android:id/tweet_profile_image',
#                                        'class': 'android.widget.FrameLayout',
#                                        'package': 'com.twitter.android',
#                                        'content-desc': 'Profile image',
#                                        'checkable': 'false',
#                                        'checked': 'false',
#                                        'clickable': 'true',
#                                        'enabled': 'true',
#                                        'focusable': 'true',
#                                        'focused': 'false',
#                                        'scrollable': 'false',
#                                        'long-clickable': 'false',
#                                        'password': 'false',
#                                        'selected': 'false',
#                                        'bounds': [33, 198, 182, 270],
#                                        'children': [{'text': '',
#                                          'resource-id': '',
#                                          'class': 'android.widget.ImageView',
#                                          'package': 'com.twitter.android',
#                                          'content-desc': '',
#                                          'checkable': 'false',
#                                          'checked': 'false',
#                                          'clickable': 'false',
#                                          'enabled': 'true',
#                                          'focusable': 'false',
#                                          'focused': 'false',
#                                          'scrollable': 'false',
#                                          'long-clickable': 'false',
#                                          'password': 'false',
#                                          'selected': 'false',
#                                          'bounds': [33, 198, 182, 270]}]}]},
#                                     {'text': '',
#                                      'resource-id': 'com.twitter.android:id/tweet_content_text',
#                                      'class': 'android.view.View',
#                                      'package': 'com.twitter.android',
#                                      'content-desc': '',
#                                      'checkable': 'false',
#                                      'checked': 'false',
#                                      'clickable': 'false',
#                                      'enabled': 'true',
#                                      'focusable': 'true',
#                                      'focused': 'false',
#                                      'scrollable': 'false',
#                                      'long-clickable': 'false',
#                                      'password': 'false',
#                                      'selected': 'false',
#                                      'bounds': [210, 198, 1047, 553],
#                                      'children': [{'text': 'George Orwell, 1984: â€œEvery record has been destroyed or falsified, every book has been rewritten, every picture has been repainted, every statue and street and building has been renamed, every date has been altered. And that process is continuing day by day and minute by minute.â€¦ Show more',
#                                        'resource-id': '',
#                                        'class': 'android.view.View',
#                                        'package': 'com.twitter.android',
#                                        'content-desc': '',
#                                        'checkable': 'false',
#                                        'checked': 'false',
#                                        'clickable': 'false',
#                                        'enabled': 'true',
#                                        'focusable': 'true',
#                                        'focused': 'false',
#                                        'scrollable': 'false',
#                                        'long-clickable': 'false',
#                                        'password': 'false',
#                                        'selected': 'false',
#                                        'bounds': [210, 198, 1047, 553]}]},
#                                     {'text': '',
#                                      'resource-id': 'com.twitter.android:id/tweet_connector_bottom',
#                                      'class': 'android.view.View',
#                                      'package': 'com.twitter.android',
#                                      'content-desc': '',
#                                      'checkable': 'false',
#                                      'checked': 'false',
#                                      'clickable': 'false',
#                                      'enabled': 'true',
#                                      'focusable': 'false',
#                                      'focused': 'false',
#                                      'scrollable': 'false',
#                                      'long-clickable': 'false',
#                                      'password': 'false',
#                                      'selected': 'false',
#                                      'bounds': [105, 276, 111, 2060]},
#                                     {'text': '',
#                                      'resource-id': 'com.twitter.android:id/tweet_quote',
#                                      'class': 'android.view.ViewGroup',
#                                      'package': 'com.twitter.android',
#                                      'content-desc': 'Walter Kirn @walterkirn Verified.    Writers may wish to rethink their ambitions. If their work should prove lastng, it may end up being tortured for all eternity\n\nThis is not mere "sensitivity" editing, by the way. This is blunt, agenda-driven rewriting. It is idea injection. And it will be continual once it starts pic.twitter.com/LX6ZSpPgui.           Show this thread.    ',
#                                      'checkable': 'false',
#                                      'checked': 'false',
#                                      'clickable': 'true',
#                                      'enabled': 'true',
#                                      'focusable': 'true',
#                                      'focused': 'false',
#                                      'scrollable': 'false',
#                                      'long-clickable': 'true',
#                                      'password': 'false',
#                                      'selected': 'false',
#                                      'bounds': [210, 572, 1047, 2037],
#                                      'children': [{'text': '',
#                                        'resource-id': '',
#                                        'class': 'android.widget.FrameLayout',
#                                        'package': 'com.twitter.android',
#                                        'content-desc': '',
#                                        'checkable': 'false',
#                                        'checked': 'false',
#                                        'clickable': 'false',
#                                        'enabled': 'true',
#                                        'focusable': 'false',
#                                        'focused': 'false',
#                                        'scrollable': 'false',
#                                        'long-clickable': 'false',
#                                        'password': 'false',
#                                        'selected': 'false',
#                                        'bounds': [244, 601, 299, 656],
#                                        'children': [{'text': '',
#                                          'resource-id': '',
#                                          'class': 'android.widget.ImageView',
#                                          'package': 'com.twitter.android',
#                                          'content-desc': '',
#                                          'checkable': 'false',
#                                          'checked': 'false',
#                                          'clickable': 'false',
#                                          'enabled': 'true',
#                                          'focusable': 'false',
#                                          'focused': 'false',
#                                          'scrollable': 'false',
#                                          'long-clickable': 'false',
#                                          'password': 'false',
#                                          'selected': 'false',
#                                          'bounds': [244, 601, 299, 656]}]},
#                                       {'text': '',
#                                        'resource-id': '',
#                                        'class': 'android.view.ViewGroup',
#                                        'package': 'com.twitter.android',
#                                        'content-desc': '',
#                                        'checkable': 'false',
#                                        'checked': 'false',
#                                        'clickable': 'false',
#                                        'enabled': 'true',
#                                        'focusable': 'false',
#                                        'focused': 'false',
#                                        'scrollable': 'false',
#                                        'long-clickable': 'false',
#                                        'password': 'false',
#                                        'selected': 'false',
#                                        'bounds': [310, 611, 1013, 655]},
#                                       {'text': '',
#                                        'resource-id': '',
#                                        'class': 'android.view.ViewGroup',
#                                        'package': 'com.twitter.android',
#                                        'content-desc': '',
#                                        'checkable': 'false',
#                                        'checked': 'false',
#                                        'clickable': 'false',
#                                        'enabled': 'true',
#                                        'focusable': 'false',
#                                        'focused': 'false',
#                                        'scrollable': 'false',
#                                        'long-clickable': 'false',
#                                        'password': 'false',
#                                        'selected': 'false',
#                                        'bounds': [244, 951, 1013, 994],
#                                        'children': [{'text': '',
#                                          'resource-id': 'com.twitter.android:id/tweet_additional_context_text',
#                                          'class': 'android.view.View',
#                                          'package': 'com.twitter.android',
#                                          'content-desc': 'Show this thread',
#                                          'checkable': 'false',
#                                          'checked': 'false',
#                                          'clickable': 'false',
#                                          'enabled': 'true',
#                                          'focusable': 'false',
#                                          'focused': 'false',
#                                          'scrollable': 'false',
#                                          'long-clickable': 'false',
#                                          'password': 'false',
#                                          'selected': 'false',
#                                          'bounds': [244, 951, 514, 994]}]},
#                                       {'text': '',
#                                        'resource-id': '',
#                                        'class': 'android.widget.FrameLayout',
#                                        'package': 'com.twitter.android',
#                                        'content-desc': '',
#                                        'checkable': 'false',
#                                        'checked': 'false',
#                                        'clickable': 'false',
#                                        'enabled': 'true',
#                                        'focusable': 'false',
#                                        'focused': 'false',
#                                        'scrollable': 'false',
#                                        'long-clickable': 'false',
#                                        'password': 'false',
#                                        'selected': 'false',
#                                        'bounds': [211, 1027, 1046, 2037],
#                                        'children': [{'text': '',
#                                          'resource-id': '',
#                                          'class': 'android.view.ViewGroup',
#                                          'package': 'com.twitter.android',
#                                          'content-desc': '',
#                                          'checkable': 'false',
#                                          'checked': 'false',
#                                          'clickable': 'true',
#                                          'enabled': 'true',
#                                          'focusable': 'true',
#                                          'focused': 'false',
#                                          'scrollable': 'false',
#                                          'long-clickable': 'false',
#                                          'password': 'false',
#                                          'selected': 'false',
#                                          'bounds': [211, 1027, 1046, 2037],
#                                          'children': [{'text': '',
#                                            'resource-id': '',
#                                            'class': 'android.widget.FrameLayout',
#                                            'package': 'com.twitter.android',
#                                            'content-desc': 'Image',
#                                            'checkable': 'false',
#                                            'checked': 'false',
#                                            'clickable': 'true',
#                                            'enabled': 'true',
#                                            'focusable': 'true',
#                                            'focused': 'false',
#                                            'scrollable': 'false',
#                                            'long-clickable': 'false',
#                                            'password': 'false',
#                                            'selected': 'false',
#                                            'bounds': [211, 1027, 1046, 2037],
#                                            'children': [{'text': '',
#                                              'resource-id': '',
#                                              'class': 'android.widget.ImageView',
#                                              'package': 'com.twitter.android',
#                                              'content-desc': '',
#                                              'checkable': 'false',
#                                              'checked': 'false',
#                                              'clickable': 'false',
#                                              'enabled': 'true',
#                                              'focusable': 'false',
#                                              'focused': 'false',
#                                              'scrollable': 'false',
#                                              'long-clickable': 'false',
#                                              'password': 'false',
#                                              'selected': 'false',
#                                              'bounds': [211,
#                                               1027,
#                                               1046,
#                                               2037]}]}]}]}]},
#                                     {'text': '',
#                                      'resource-id': 'com.twitter.android:id/tweet_inline_actions',
#                                      'class': 'android.widget.FrameLayout',
#                                      'package': 'com.twitter.android',
#                                      'content-desc': '',
#                                      'checkable': 'false',
#                                      'checked': 'false',
#                                      'clickable': 'false',
#                                      'enabled': 'true',
#                                      'focusable': 'false',
#                                      'focused': 'false',
#                                      'scrollable': 'false',
#                                      'long-clickable': 'false',
#                                      'password': 'false',
#                                      'selected': 'false',
#                                      'bounds': [182, 2037, 1047, 2060],
#                                      'children': [{'text': '',
#                                        'resource-id': '',
#                                        'class': 'android.view.ViewGroup',
#                                        'package': 'com.twitter.android',
#                                        'content-desc': '',
#                                        'checkable': 'false',
#                                        'checked': 'false',
#                                        'clickable': 'false',
#                                        'enabled': 'true',
#                                        'focusable': 'false',
#                                        'focused': 'false',
#                                        'scrollable': 'false',
#                                        'long-clickable': 'false',
#                                        'password': 'false',
#                                        'selected': 'false',
#                                        'bounds': [182, 2037, 1047, 2060],
#                                        'children': [{'text': '',
#                                          'resource-id': 'com.twitter.android:id/inline_reply',
#                                          'class': 'android.view.ViewGroup',
#                                          'package': 'com.twitter.android',
#                                          'content-desc': '',
#                                          'checkable': 'false',
#                                          'checked': 'false',
#                                          'clickable': 'true',
#                                          'enabled': 'true',
#                                          'focusable': 'true',
#                                          'focused': 'false',
#                                          'scrollable': 'false',
#                                          'long-clickable': 'false',
#                                          'password': 'false',
#                                          'selected': 'false',
#                                          'bounds': [182, 2037, 370, 2060],
#                                          'children': [{'text': '',
#                                            'resource-id': '',
#                                            'class': 'android.widget.FrameLayout',
#                                            'package': 'com.twitter.android',
#                                            'content-desc': '',
#                                            'checkable': 'false',
#                                            'checked': 'false',
#                                            'clickable': 'false',
#                                            'enabled': 'true',
#                                            'focusable': 'false',
#                                            'focused': 'false',
#                                            'scrollable': 'false',
#                                            'long-clickable': 'false',
#                                            'password': 'false',
#                                            'selected': 'false',
#                                            'bounds': [182, 2037, 292, 2060]}]},
#                                         {'text': '',
#                                          'resource-id': 'com.twitter.android:id/inline_retweet',
#                                          'class': 'android.view.ViewGroup',
#                                          'package': 'com.twitter.android',
#                                          'content-desc': '',
#                                          'checkable': 'false',
#                                          'checked': 'false',
#                                          'clickable': 'true',
#                                          'enabled': 'true',
#                                          'focusable': 'true',
#                                          'focused': 'false',
#                                          'scrollable': 'false',
#                                          'long-clickable': 'false',
#                                          'password': 'false',
#                                          'selected': 'false',
#                                          'bounds': [370, 2037, 558, 2060],
#                                          'children': [{'text': '',
#                                            'resource-id': '',
#                                            'class': 'android.widget.FrameLayout',
#                                            'package': 'com.twitter.android',
#                                            'content-desc': '',
#                                            'checkable': 'false',
#                                            'checked': 'false',
#                                            'clickable': 'false',
#                                            'enabled': 'true',
#                                            'focusable': 'false',
#                                            'focused': 'false',
#                                            'scrollable': 'false',
#                                            'long-clickable': 'false',
#                                            'password': 'false',
#                                            'selected': 'false',
#                                            'bounds': [370, 2037, 480, 2060]}]},
#                                         {'text': '',
#                                          'resource-id': 'com.twitter.android:id/inline_like',
#                                          'class': 'android.view.ViewGroup',
#                                          'package': 'com.twitter.android',
#                                          'content-desc': '',
#                                          'checkable': 'false',
#                                          'checked': 'false',
#                                          'clickable': 'true',
#                                          'enabled': 'true',
#                                          'focusable': 'true',
#                                          'focused': 'false',
#                                          'scrollable': 'false',
#                                          'long-clickable': 'false',
#                                          'password': 'false',
#                                          'selected': 'false',
#                                          'bounds': [558, 2037, 746, 2060],
#                                          'children': [{'text': '',
#                                            'resource-id': '',
#                                            'class': 'android.widget.FrameLayout',
#                                            'package': 'com.twitter.android',
#                                            'content-desc': '',
#                                            'checkable': 'false',
#                                            'checked': 'false',
#                                            'clickable': 'false',
#                                            'enabled': 'true',
#                                            'focusable': 'false',
#                                            'focused': 'false',
#                                            'scrollable': 'false',
#                                            'long-clickable': 'false',
#                                            'password': 'false',
#                                            'selected': 'false',
#                                            'bounds': [558, 2037, 668, 2060]}]},
#                                         {'text': '',
#                                          'resource-id': 'com.twitter.android:id/inline_view_count',
#                                          'class': 'android.view.ViewGroup',
#                                          'package': 'com.twitter.android',
#                                          'content-desc': '',
#                                          'checkable': 'false',
#                                          'checked': 'false',
#                                          'clickable': 'true',
#                                          'enabled': 'true',
#                                          'focusable': 'true',
#                                          'focused': 'false',
#                                          'scrollable': 'false',
#                                          'long-clickable': 'false',
#                                          'password': 'false',
#                                          'selected': 'false',
#                                          'bounds': [746, 2037, 934, 2060],
#                                          'children': [{'text': '',
#                                            'resource-id': '',
#                                            'class': 'android.widget.FrameLayout',
#                                            'package': 'com.twitter.android',
#                                            'content-desc': '',
#                                            'checkable': 'false',
#                                            'checked': 'false',
#                                            'clickable': 'false',
#                                            'enabled': 'true',
#                                            'focusable': 'false',
#                                            'focused': 'false',
#                                            'scrollable': 'false',
#                                            'long-clickable': 'false',
#                                            'password': 'false',
#                                            'selected': 'false',
#                                            'bounds': [746, 2037, 856, 2060]}]},
#                                         {'NAF': 'true',
#                                          'text': '',
#                                          'resource-id': 'com.twitter.android:id/inline_twitter_share',
#                                          'class': 'android.view.ViewGroup',
#                                          'package': 'com.twitter.android',
#                                          'content-desc': '',
#                                          'checkable': 'false',
#                                          'checked': 'false',
#                                          'clickable': 'true',
#                                          'enabled': 'true',
#                                          'focusable': 'true',
#                                          'focused': 'false',
#                                          'scrollable': 'false',
#                                          'long-clickable': 'false',
#                                          'password': 'false',
#                                          'selected': 'false',
#                                          'bounds': [934, 2037, 1047, 2060],
#                                          'children': [{'text': '',
#                                            'resource-id': '',
#                                            'class': 'android.widget.FrameLayout',
#                                            'package': 'com.twitter.android',
#                                            'content-desc': '',
#                                            'checkable': 'false',
#                                            'checked': 'false',
#                                            'clickable': 'false',
#                                            'enabled': 'true',
#                                            'focusable': 'false',
#                                            'focused': 'false',
#                                            'scrollable': 'false',
#                                            'long-clickable': 'false',
#                                            'password': 'false',
#                                            'selected': 'false',
#                                            'bounds': [934,
#                                             2037,
#                                             1044,
#                                             2060]}]}]}]}]}]}]}]}]}]}]}]}]}]},
#                 {'text': '',
#                  'resource-id': '',
#                  'class': 'android.view.ViewGroup',
#                  'package': 'com.twitter.android',
#                  'content-desc': '',
#                  'checkable': 'false',
#                  'checked': 'false',
#                  'clickable': 'false',
#                  'enabled': 'true',
#                  'focusable': 'false',
#                  'focused': 'false',
#                  'scrollable': 'false',
#                  'long-clickable': 'false',
#                  'password': 'false',
#                  'selected': 'false',
#                  'bounds': [882, 1862, 1080, 2060],
#                  'children': [{'text': '',
#                    'resource-id': 'com.twitter.android:id/composer_write',
#                    'class': 'android.widget.ImageButton',
#                    'package': 'com.twitter.android',
#                    'content-desc': 'New Tweet',
#                    'checkable': 'false',
#                    'checked': 'false',
#                    'clickable': 'true',
#                    'enabled': 'true',
#                    'focusable': 'true',
#                    'focused': 'false',
#                    'scrollable': 'false',
#                    'long-clickable': 'false',
#                    'password': 'false',
#                    'selected': 'false',
#                    'bounds': [882, 1862, 1036, 2016]}]},
#                 {'text': '',
#                  'resource-id': 'com.twitter.android:id/bottom_bar',
#                  'class': 'android.widget.LinearLayout',
#                  'package': 'com.twitter.android',
#                  'content-desc': '',
#                  'checkable': 'false',
#                  'checked': 'false',
#                  'clickable': 'false',
#                  'enabled': 'true',
#                  'focusable': 'false',
#                  'focused': 'false',
#                  'scrollable': 'false',
#                  'long-clickable': 'false',
#                  'password': 'false',
#                  'selected': 'false',
#                  'bounds': [0, 2060, 1080, 2214],
#                  'children': [{'text': '',
#                    'resource-id': '',
#                    'class': 'android.widget.FrameLayout',
#                    'package': 'com.twitter.android',
#                    'content-desc': '',
#                    'checkable': 'false',
#                    'checked': 'false',
#                    'clickable': 'false',
#                    'enabled': 'true',
#                    'focusable': 'false',
#                    'focused': 'false',
#                    'scrollable': 'false',
#                    'long-clickable': 'false',
#                    'password': 'false',
#                    'selected': 'false',
#                    'bounds': [0, 2060, 1080, 2214],
#                    'children': [{'text': '',
#                      'resource-id': 'com.twitter.android:id/tabs',
#                      'class': 'android.widget.HorizontalScrollView',
#                      'package': 'com.twitter.android',
#                      'content-desc': '',
#                      'checkable': 'false',
#                      'checked': 'false',
#                      'clickable': 'false',
#                      'enabled': 'true',
#                      'focusable': 'true',
#                      'focused': 'false',
#                      'scrollable': 'false',
#                      'long-clickable': 'false',
#                      'password': 'false',
#                      'selected': 'false',
#                      'bounds': [0, 2060, 1080, 2214],
#                      'children': [{'text': '',
#                        'resource-id': '',
#                        'class': 'android.widget.LinearLayout',
#                        'package': 'com.twitter.android',
#                        'content-desc': '',
#                        'checkable': 'false',
#                        'checked': 'false',
#                        'clickable': 'false',
#                        'enabled': 'true',
#                        'focusable': 'false',
#                        'focused': 'false',
#                        'scrollable': 'false',
#                        'long-clickable': 'false',
#                        'password': 'false',
#                        'selected': 'false',
#                        'bounds': [0, 2060, 1080, 2214],
#                        'children': [{'text': '',
#                          'resource-id': '',
#                          'class': 'android.widget.LinearLayout',
#                          'package': 'com.twitter.android',
#                          'content-desc': 'Home. New items',
#                          'checkable': 'false',
#                          'checked': 'false',
#                          'clickable': 'false',
#                          'enabled': 'true',
#                          'focusable': 'true',
#                          'focused': 'false',
#                          'scrollable': 'false',
#                          'long-clickable': 'false',
#                          'password': 'false',
#                          'selected': 'true',
#                          'bounds': [0, 2060, 216, 2214],
#                          'children': [{'text': '',
#                            'resource-id': 'com.twitter.android:id/channels',
#                            'class': 'android.view.View',
#                            'package': 'com.twitter.android',
#                            'content-desc': '',
#                            'checkable': 'false',
#                            'checked': 'false',
#                            'clickable': 'false',
#                            'enabled': 'true',
#                            'focusable': 'false',
#                            'focused': 'false',
#                            'scrollable': 'false',
#                            'long-clickable': 'false',
#                            'password': 'false',
#                            'selected': 'true',
#                            'bounds': [33, 2060, 183, 2214]}]},
#                         {'text': '',
#                          'resource-id': '',
#                          'class': 'android.widget.LinearLayout',
#                          'package': 'com.twitter.android',
#                          'content-desc': 'Search and Explore',
#                          'checkable': 'false',
#                          'checked': 'false',
#                          'clickable': 'true',
#                          'enabled': 'true',
#                          'focusable': 'true',
#                          'focused': 'false',
#                          'scrollable': 'false',
#                          'long-clickable': 'false',
#                          'password': 'false',
#                          'selected': 'false',
#                          'bounds': [216, 2060, 432, 2214],
#                          'children': [{'text': '',
#                            'resource-id': '',
#                            'class': 'android.view.View',
#                            'package': 'com.twitter.android',
#                            'content-desc': '',
#                            'checkable': 'false',
#                            'checked': 'false',
#                            'clickable': 'false',
#                            'enabled': 'true',
#                            'focusable': 'false',
#                            'focused': 'false',
#                            'scrollable': 'false',
#                            'long-clickable': 'false',
#                            'password': 'false',
#                            'selected': 'false',
#                            'bounds': [249, 2060, 399, 2214]}]},
#                         {'text': '',
#                          'resource-id': '',
#                          'class': 'android.widget.LinearLayout',
#                          'package': 'com.twitter.android',
#                          'content-desc': 'Spaces',
#                          'checkable': 'false',
#                          'checked': 'false',
#                          'clickable': 'true',
#                          'enabled': 'true',
#                          'focusable': 'true',
#                          'focused': 'false',
#                          'scrollable': 'false',
#                          'long-clickable': 'false',
#                          'password': 'false',
#                          'selected': 'false',
#                          'bounds': [432, 2060, 648, 2214],
#                          'children': [{'text': '',
#                            'resource-id': 'com.twitter.android:id/spaces',
#                            'class': 'android.view.View',
#                            'package': 'com.twitter.android',
#                            'content-desc': '',
#                            'checkable': 'false',
#                            'checked': 'false',
#                            'clickable': 'false',
#                            'enabled': 'true',
#                            'focusable': 'false',
#                            'focused': 'false',
#                            'scrollable': 'false',
#                            'long-clickable': 'false',
#                            'password': 'false',
#                            'selected': 'false',
#                            'bounds': [465, 2060, 615, 2214]}]},
#                         {'text': '',
#                          'resource-id': '',
#                          'class': 'android.widget.LinearLayout',
#                          'package': 'com.twitter.android',
#                          'content-desc': 'Notifications',
#                          'checkable': 'false',
#                          'checked': 'false',
#                          'clickable': 'true',
#                          'enabled': 'true',
#                          'focusable': 'true',
#                          'focused': 'false',
#                          'scrollable': 'false',
#                          'long-clickable': 'false',
#                          'password': 'false',
#                          'selected': 'false',
#                          'bounds': [648, 2060, 864, 2214],
#                          'children': [{'text': '',
#                            'resource-id': 'com.twitter.android:id/notifications',
#                            'class': 'android.view.View',
#                            'package': 'com.twitter.android',
#                            'content-desc': '',
#                            'checkable': 'false',
#                            'checked': 'false',
#                            'clickable': 'false',
#                            'enabled': 'true',
#                            'focusable': 'false',
#                            'focused': 'false',
#                            'scrollable': 'false',
#                            'long-clickable': 'false',
#                            'password': 'false',
#                            'selected': 'false',
#                            'bounds': [681, 2060, 831, 2214]}]},
#                         {'text': '',
#                          'resource-id': '',
#                          'class': 'android.widget.LinearLayout',
#                          'package': 'com.twitter.android',
#                          'content-desc': 'Messages',
#                          'checkable': 'false',
#                          'checked': 'false',
#                          'clickable': 'true',
#                          'enabled': 'true',
#                          'focusable': 'true',
#                          'focused': 'false',
#                          'scrollable': 'false',
#                          'long-clickable': 'false',
#                          'password': 'false',
#                          'selected': 'false',
#                          'bounds': [864, 2060, 1080, 2214],
#                          'children': [{'text': '',
#                            'resource-id': 'com.twitter.android:id/dms',
#                            'class': 'android.view.View',
#                            'package': 'com.twitter.android',
#                            'content-desc': '',
#                            'checkable': 'false',
#                            'checked': 'false',
#                            'clickable': 'false',
#                            'enabled': 'true',
#                            'focusable': 'false',
#                            'focused': 'false',
#                            'scrollable': 'false',
#                            'long-clickable': 'false',
#                            'password': 'false',
#                            'selected': 'false',
#                            'bounds': [897,
#                             2060,
#                             1047,
#                             2214]}]}]}]}]}]}]}]}]}]}]}]},
#     {'text': '',
#      'resource-id': 'android:id/statusBarBackground',
#      'class': 'android.view.View',
#      'package': 'com.twitter.android',
#      'content-desc': '',
#      'checkable': 'false',
#      'checked': 'false',
#      'clickable': 'false',
#      'enabled': 'true',
#      'focusable': 'false',
#      'focused': 'false',
#      'scrollable': 'false',
#      'long-clickable': 'false',
#      'password': 'false',
#      'selected': 'false',
#      'bounds': [0, 0, 1080, 66]},
#     {'text': '',
#      'resource-id': 'android:id/navigationBarBackground',
#      'class': 'android.view.View',
#      'package': 'com.twitter.android',
#      'content-desc': '',
#      'checkable': 'false',
#      'checked': 'false',
#      'clickable': 'false',
#      'enabled': 'true',
#      'focusable': 'false',
#      'focused': 'false',
#      'scrollable': 'false',
#      'long-clickable': 'false',
#      'password': 'false',
#      'selected': 'false',
#      'bounds': [0, 0, 0, 0]}]}}}
